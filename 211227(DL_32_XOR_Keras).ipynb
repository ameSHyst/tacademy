# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
x_data = np.array( [[0,0],[0,1],[1,0],[1,1]] )
y_data = np.array( [[0],[1],[1],[0] ] )

# %%
dense1 = Dense(units = 100, input_dim = 2, activation = 'sigmoid') #w : 2 X 100, b : 100   (b = label)
dense2 = Dense(units = 1, input_dim = 100, activation = 'sigmoid') #w : 100 X 1, b : 1
#dense1의 input_dim 과 dense2의 units 맞추기
model = Sequential([dense1, dense2])
model.compile(loss='binary_crossentropy', optimizer=Adam(0.1), metrics=['acc']) #로그함수 적용/ 정확도 출력
h = model.fit(x_data, y_data, epochs = 1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 262ms/step - loss: 0.7374 - acc: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5141 - acc: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 996us/step - loss: 1.1779 - acc: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9624 - acc: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 970us/step - loss: 1.4441 - acc: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 998us/step - loss: 1.2419 - acc: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.8174 - acc: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.7286 - acc: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 998us/step - loss: 0.9403 - acc: 0.5000
# Epoch 10/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0342 - acc: 0.5000
# ...

# %%
(model.predict(x_data) > 0.5) + 0
# Out:
# array([[0],
#        [1],
#        [1],
#        [0]])

# %%
w, b = dense1.get_weights()
w
# Out:
# array([[ 1.1398773 , -7.461886  , -2.8746164 , -2.0423076 , -4.617762  ,
#         -6.9565463 , -7.6526723 , -6.38876   , -7.2690034 ,  1.5022509 ,
#         -1.6932162 , -5.357241  , -1.4137683 , -1.4419839 , -1.6191491 ,
#         -2.8720467 , -1.4528283 , -1.5427355 ,  3.3935351 , -6.3151627 ,
#         -2.0923586 , -2.7431886 ,  0.91604304, -1.4157599 , -2.7947814 ,
#         -2.2340095 , -5.175427  , -3.8806598 ,  4.002934  , -7.033275  ,
#         -1.5187911 , -5.6146493 , -4.574011  , -1.7219036 , -7.287285  ,
#         -6.8696575 ,  4.1530886 ,  0.7346284 , -6.8092165 , -7.4656944 ,
#         -1.4122367 , -5.0790744 , -1.6045403 , -1.464305  , -1.5894854 ,
#          0.88926655, -1.8951468 , -1.4938788 , -0.20656097,  2.834508  ,
#         -1.6743636 , -8.585489  , -3.2368352 , -6.923969  , -2.0250344 ,
#         -7.067562  , -5.2868686 , -1.5121167 , -1.7180508 , -2.6216035 ,
#         -2.9166307 , -1.4358872 , -1.8916123 , -8.027511  , -2.4890194 ,
# ...

# %%
w, b = dense2.get_weights()
w
# Out:
# array([[ 1.2785559 ],
#        [-1.6403732 ],
#        [-0.23154464],
#        [-0.07400975],
#        [-0.65789443],
#        [-1.45005   ],
#        [ 1.7654743 ],
#        [-1.220138  ],
#        [-1.6665671 ],
#        [ 0.996781  ],
#        [ 0.1396095 ],
#        [ 0.70084536],
#        [ 0.04088701],
#        [ 0.17809719],
#        [ 0.13134477],
#        [-0.21031061],
#        [ 0.06390435],
#        [ 0.07979653],
#        [ 2.3871672 ],
#        [ 1.1332152 ],
#        [-0.07558368],
#        [ 0.68180597],
#        [ 1.1486299 ],
#        [ 0.07654568],
#        [ 0.64900595],
#        [ 0.22007234],
#        [-0.8261996 ],
#        [-0.4561374 ],
#        [ 2.2273993 ],
#        [ 1.5594468 ],
#        [ 0.09716774],
#        [ 1.0083978 ],
#        [-0.6285664 ],
#        [ 0.01487569],
#        [ 1.5148369 ],
#        [ 1.2382363 ],
#        [ 2.1238956 ],
#        [-2.8265479 ],
#        [-1.3307811 ],
#        [-1.6051621 ],
#        [ 0.16956823],
# ...

# %%
# 4x2  2x100  = 4x100  100x1 = 4x1

# %%
#다른 방식
modelNN = Sequential()

modelNN.add( Dense( units=64, input_dim=2 ,activation="sigmoid") )
modelNN.add( Dense( units=32, activation="sigmoid") ) #input_dim 생략 가능
modelNN.add( Dense( units=1,  activation="sigmoid") )
modelNN.compile( loss="binary_crossentropy" ,optimizer=Adam(0.1), metrics=['acc'] )
h = modelNN.fit( x_data, y_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 255ms/step - loss: 0.7272 - acc: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9334 - acc: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 997us/step - loss: 1.4853 - acc: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 997us/step - loss: 1.0340 - acc: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7962 - acc: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7020 - acc: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 997us/step - loss: 0.7059 - acc: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7554 - acc: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7983 - acc: 0.5000
# Epoch 10/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8163 - acc: 0.5000
# Epoch 11/1000
# ...

# %%
(modelNN.predict(x_data) > 0.5)
# Out:
# array([[False],
#        [ True],
#        [ True],
#        [False]])

# %%
modelNN.layers

# %%
w, b = modelNN.layers[0].get_weights()
w
# Out:
# array([[-3.082867  , -2.1094048 , -2.9078996 , -3.4814858 , -3.314244  ,
#         -4.2811327 , -3.546597  , -2.7099404 ,  4.6578436 , -1.4015538 ,
#         -3.097973  , -2.5292125 , -2.9863982 , -0.23225577, -2.9071875 ,
#         -2.8218904 , -0.5581507 , -2.396793  , -3.972141  , -2.2207668 ,
#         -3.1815438 , -2.4598174 , -3.8314612 , -3.3421035 , -1.6764555 ,
#         -2.332776  , -2.490134  , -0.19854915, -2.9015617 , -0.8645208 ,
#         -3.465594  , -1.2095956 , -2.6769023 , -1.6224954 , -1.1969215 ,
#         -4.1450067 , -3.6639576 , -3.1199229 , -5.0717    , -4.0757732 ,
#         -0.49846312, -2.9925272 , -2.7013123 , -3.394151  , -3.4473195 ,
#         -0.5680939 , -3.7219334 , -0.58656645, -4.0372334 , -4.0419893 ,
#         -3.1650639 , -2.9000607 , -2.403754  , -1.031198  , -4.0292797 ,
#         -1.803571  , -0.6886285 , -2.2284703 , -0.76375866, -3.4196258 ,
#         -3.1806214 , -1.837216  , -3.3353484 , -3.416426  ],
# ...

# %%
w, b = modelNN.layers[1].get_weights()
w
# Out:
# array([[ 0.33472434, -0.92954266, -0.49402836, ..., -0.69573516,
#         -0.6961548 , -0.5707266 ],
#        [ 0.6400926 , -0.5197193 , -0.8274933 , ..., -0.41476667,
#         -1.0594199 , -0.6635279 ],
#        [ 0.40547097, -0.42500412, -0.77415556, ..., -0.4473298 ,
#         -1.213997  , -0.89675874],
#        ...,
#        [ 0.0810698 ,  0.42216897, -0.814945  , ...,  0.24900645,
#         -0.89801854, -0.48496777],
#        [ 0.55822915, -0.98727465, -0.73697907, ..., -1.1487032 ,
#         -1.2700083 , -0.7173974 ],
#        [ 0.41097856, -1.0242949 , -0.91675705, ..., -1.1422963 ,
#         -0.9499098 , -0.66613716]], dtype=float32)
