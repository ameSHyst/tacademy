# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df = pd.read_csv('data/test.csv', header=None)
df.columns=['q1','q2','mid','final']
df
# Out:
#     q1  q2  mid  final
# 0   73  80   75    152
# 1   93  88   93    185
# 2   89  91   90    180
# 3   96  98  100    196
# 4   73  66   70    142
# 5   53  46   55    101
# 6   69  74   77    149
# 7   47  56   60    115
# 8   87  79   90    175
# 9   79  70   88    164
# 10  69  70   73    141
# 11  70  65   74    141
# 12  93  95   91    184
# 13  79  80   73    152
# 14  70  73   78    148
# 15  93  89   96    192
# 16  78  75   68    147
# 17  81  90   93    183
# 18  88  92   86    177
# 19  78  83   77    159
# 20  82  86   90    177
# 21  86  82   89    175
# 22  78  83   85    175
# 23  76  83   71    149
# 24  96  93   95    192

# %%
x_data = df.iloc[:,:-1].values #특성데이터 추출
y_data = df.iloc[:, [-1]].values

# %%
dense = Dense(units = 1, input_dim = 3) #w : 3 X 1, b : 1
model = Sequential( [dense] )
model.compile(loss = 'mse', optimizer = Adam(0.1))
h = model.fit(x_data, y_data, epochs = 500) #행렬로 주어져야
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 175ms/step - loss: 79256.1797
# Epoch 2/500
# 1/1 [==============================] - 0s 998us/step - loss: 66145.6641
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 54258.6445
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 43611.1211
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 34210.4688
# Epoch 6/500
# 1/1 [==============================] - 0s 997us/step - loss: 26053.0684
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 19122.5020
# Epoch 8/500
# 1/1 [==============================] - 0s 997us/step - loss: 13387.3779
# Epoch 9/500
# 1/1 [==============================] - 0s 995us/step - loss: 8799.1836
# Epoch 10/500
# 1/1 [==============================] - 0s 999us/step - loss: 5290.7417
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2775.2678
# Epoch 12/500
# ...

# %%
w, b = dense.get_weights()

# %%
w
# Out:
# array([[0.48986492],
#        [1.0858601 ],
#        [0.4399535 ]], dtype=float32)

# %%
#q1 = 80, q2 = 90, mid = 90인 경우의 final 예측
model.predict( [[80,90,90]] )
# Out:
# array([[177.68707]], dtype=float32)

# %% [markdown]
# #### 체크 포인트
#     1) 상관관계
#     2) 정규화
#     3) 다중공선성
